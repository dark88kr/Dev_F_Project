# %%
# !pip install pm4py

import pandas as pd
import pm4py
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.util import dataframe_utils
from pm4py.visualization.process_tree import visualizer as pt_visualizer
from pm4py.algo.discovery.alpha import algorithm as alpha_miner
from pm4py.visualization.petri_net import visualizer as pn_visualizer
from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
from pm4py.visualization.heuristics_net import visualizer as hn_visualizer
# Out:
# Collecting pm4py
#   Downloading pm4py-2.7.15-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pm4py) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pm4py) (2.2.2)
# Collecting deprecation (from pm4py)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pm4py) (3.4.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from pm4py) (0.20.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from pm4py) (0.45.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pm4py) (75.2.0)
# Collecting intervaltree (from pm4py)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from pm4py) (5.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pm4py) (3.10.0)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.11/dist-packages (from pm4py) (2.0.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from pm4py) (2025.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pm4py) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from pm4py) (4.67.1)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.11/dist-packages (from pm4py) (1.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from deprecation->pm4py) (24.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from intervaltree->pm4py) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pm4py) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pm4py) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pm4py) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pm4py) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pm4py) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pm4py) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pm4py) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pm4py) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pm4py) (1.17.0)
# Downloading pm4py-2.7.15-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 54.3 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: intervaltree
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26098 sha256=c4428ef9165d4bea2b5597ce14308733d8934e64ab13736cc0b6a5be4b3fbd83
#   Stored in directory: /root/.cache/pip/wheels/31/d7/d9/eec6891f78cac19a693bd40ecb8365d2f4613318c145ec9816
# Successfully built intervaltree
# Installing collected packages: intervaltree, deprecation, pm4py
# Successfully installed deprecation-2.1.0 intervaltree-3.1.0 pm4py-2.7.15

# %%
df = pd.read_csv('/content/drive/MyDrive/DEV/PROJECT/201608.csv')

# %%
df['date'].unique()
# Out:
# array([20160820, 20160827, 20160816, 20160824, 20160807, 20160829,
#        20160823, 20160801, 20160821, 20160828, 20160818, 20160826,
#        20160805, 20160814, 20160819, 20160809, 20160825, 20160811,
#        20160804, 20160830, 20160810, 20160803, 20160808, 20160806,
#        20160831, 20160822, 20160812, 20160802, 20160813, 20160817,
#        20160815])

# %%
w1_df = df[(df['date'] >= 20160801) & (df['date'] <= 20160807)]

# %%
w1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 792487 entries, 33 to 4253333
# Data columns (total 75 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   fullVisitorId             792487 non-null  uint64
#  1   visitId                   792487 non-null  int64
#  2   channelGrouping           792487 non-null  object
#  3   visitNumber               792487 non-null  int64
#  4   visitStartTime            792487 non-null  int64
#  5   date                      792487 non-null  int64
#  6   hits                      792487 non-null  int64
#  7   pageviews                 792484 non-null  float64
#  8   timeOnSite                756932 non-null  float64
#  9   newVisits                 530742 non-null  float64
#  10  transactionRevenue        37540 non-null   float64
#  11  transactions              37540 non-null   float64
#  12  bounces                   35376 non-null   float64
#  13  totalTransactionRevenue   37540 non-null   float64
#  14  campaign                  792487 non-null  object
#  15  referralPath              227793 non-null  object
#  16  medium                    792487 non-null  object
#  17  source                    792487 non-null  object
#  18  keyword                   353977 non-null  object
#  19  adContent                 4977 non-null    object
#  20  browser                   792487 non-null  object
#  21  deviceCategory            792487 non-null  object
#  22  isMobile                  792487 non-null  bool
#  23  operatingSystem           792487 non-null  object
#  24  continent                 792487 non-null  object
#  25  longitude                 792487 non-null  object
#  26  latitude                  792487 non-null  object
#  27  city                      792487 non-null  object
#  28  region                    792487 non-null  object
#  29  country                   792487 non-null  object
#  30  subContinent              792487 non-null  object
#  31  metro                     792487 non-null  object
#  32  hitNumber                 792487 non-null  int64
#  33  referer                   69233 non-null   object
#  34  isExit                    128740 non-null  object
#  35  isEntrance                80636 non-null   object
#  36  isInteraction             792487 non-null  bool
#  37  minute                    792487 non-null  int64
#  38  hour                      792487 non-null  int64
#  39  time                      792487 non-null  int64
#  40  type                      792487 non-null  object
#  41  dataSource                0 non-null       float64
#  42  pagePath                  792487 non-null  object
#  43  pageTitle                 792457 non-null  object
#  44  screenName                792487 non-null  object
#  45  exitScreenName            792487 non-null  object
#  46  landingScreenName         792487 non-null  object
#  47  isFatal                   792487 non-null  bool
#  48  eventAction               22036 non-null   object
#  49  eventLabel                12725 non-null   object
#  50  v2ProductName             716411 non-null  object
#  51  productListPosition       716411 non-null  float64
#  52  productListName           716411 non-null  object
#  53  isClick                   14206 non-null   object
#  54  isImpression              678389 non-null  object
#  55  productQuantity           7626 non-null    float64
#  56  productPrice              716411 non-null  float64
#  57  productRevenue            535 non-null     float64
#  58  v2ProductCategory         716411 non-null  object
#  59  promoId                   49373 non-null   object
#  60  promoPosition             49373 non-null   object
#  61  promoCreative             49373 non-null   object
#  62  promoName                 49373 non-null   object
#  63  promoIsClick              2690 non-null    object
#  64  action_type               792487 non-null  int64
#  65  step                      792487 non-null  int64
#  66  socialNetwork             792487 non-null  object
#  67  hasSocialSourceReferral   792487 non-null  object
#  68  contentGroup1             792487 non-null  object
#  69  previousContentGroup1     792487 non-null  object
#  70  contentGroupUniqueViews3  109471 non-null  float64
#  71  contentGroupUniqueViews2  379091 non-null  float64
#  72  contentGroupUniqueViews1  27866 non-null   float64
#  73  previousContentGroup2     792487 non-null  object
#  74  contentGroup2             792487 non-null  object
# dtypes: bool(3), float64(15), int64(11), object(45), uint64(1)
# memory usage: 443.6+ MB

# %%
# 세션 ID를 fullVisitorId와 visitId를 합쳐서 만듦
w1_df['session_id'] = w1_df['fullVisitorId'].astype(str) + '_' + w1_df['visitId'].astype(str)

# 프로세스 마이닝용 컬럼으로 이름 변경
w1_df = w1_df.rename(columns={
    'session_id': 'case:concept:name',   # 프로세스의 케이스 ID # 하나의 세션/사례(case)를 구분하는 ID로 설정
    'pagePath': 'concept:name',          # 이벤트 이름 # 이벤트(Activity) 이름. 페이지 경로가 곧 이벤트 이름
    'time': 'time:timestamp'        # 타임스탬프  # 이벤트가 발생한 시간. 프로세스 순서를 위한 기준
})

# 타임스탬프 컬럼을 datetime 형식으로 변환 (ms 단위)
# hits.time은 millisecond 단위의 숫자로 사람이 이해할 수 있는 날짜/시간 포맷을 변경
w1_df['time:timestamp'] = pd.to_datetime(w1_df['time:timestamp'], unit='ms', errors='coerce')

#필요컬럼만 선택
df_log_ready = w1_df[['case:concept:name', 'concept:name', 'time:timestamp']].dropna()
# Out:
# <ipython-input-7-c19a3ab47a4a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w1_df['session_id'] = w1_df['fullVisitorId'].astype(str) + '_' + w1_df['visitId'].astype(str)

# %%
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.util import dataframe_utils

# 1. 필요한 컬럼만 정제
df_log_ready = w1_df[['case:concept:name', 'concept:name', 'time:timestamp']].copy()

# 2. time:timestamp 컬럼이 datetime인지 확인하고 변환 (ms 단위라면)
#datetime 인지 확인 하는 과정
if not pd.api.types.is_datetime64_any_dtype(df_log_ready['time:timestamp']):
    df_log_ready['time:timestamp'] = pd.to_datetime(df_log_ready['time:timestamp'], unit='ms', errors='coerce')

# 3. null 제거 (시간이 없는 경우 제거)
df_log_ready = df_log_ready.dropna(subset=['time:timestamp'])

# %%
from pm4py.objects.conversion.log import converter as log_converter

#이벤트 로그 형태로 변경
# pandas DataFrame → Event Log
event_log = log_converter.apply(df_log_ready, variant=log_converter.Variants.TO_EVENT_LOG)

# %%
from pm4py.algo.discovery.dfg import algorithm as dfg_discovery
from pm4py.visualization.dfg import visualizer as dfg_visualization

# DFG 생성
dfg = dfg_discovery.apply(event_log)

# 시각화
gviz = dfg_visualization.apply(dfg, variant=dfg_visualization.Variants.FREQUENCY)
dfg_visualization.view(gviz)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a80e82f39982> in <cell line: 0>()
#       7 # 시각화
#       8 gviz = dfg_visualization.apply(dfg, variant=dfg_visualization.Variants.FREQUENCY)
# ----> 9 dfg_visualization.view(gviz)
#
# /usr/local/lib/python3.11/dist-packages/pm4py/visualization/dfg/visualizer.py in view(gviz, parameters)
#      95         GraphViz diagram
#      96     """
# ---> 97     return gview.view(gviz, parameters=parameters)
#      98
#      99
#
# /usr/local/lib/python3.11/dist-packages/pm4py/visualization/common/gview.py in view(gviz, parameters)
#      48             html.view(gviz, parameters=parameters)
#      49         elif vis_utils.check_visualization_inside_jupyter():
# ---> 50             vis_utils.view_image_in_jupyter(gviz.render())
#      51         elif format == "gv":
#      52             print(str(gviz))
#
# /usr/local/lib/python3.11/dist-packages/graphviz/_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/graphviz/rendering.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     120         args.append(filepath)
#     121
# --> 122         rendered = self._render(*args, **kwargs)
#     123
#     124         if cleanup:
#
# /usr/local/lib/python3.11/dist-packages/graphviz/_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/graphviz/backend/rendering.py in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     324     assert filepath is not None, 'work around pytype false alarm'
#     325
# --> 326     execute.run_check(cmd,
#     327                       cwd=filepath.parent if filepath.parent.parts else None,
#     328                       quiet=quiet,
#
# /usr/local/lib/python3.11/dist-packages/graphviz/backend/execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      76             proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      77         else:
# ---> 78             proc = subprocess.run(cmd, **kwargs)
#      79     except OSError as e:
#      80         if e.errno == errno.ENOENT:
#
# /usr/lib/python3.11/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.11/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.11/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
from pm4py.visualization.heuristics_net import visualizer as hn_visualizer

heu_net = heuristics_miner.apply_heu(event_log)
gviz = hn_visualizer.apply(heu_net)
hn_visualizer.view(gviz)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-ed26dfd89bee> in <cell line: 0>()
#       3
#       4 heu_net = heuristics_miner.apply_heu(event_log)
# ----> 5 gviz = hn_visualizer.apply(heu_net)
#       6 hn_visualizer.view(gviz)
#
# /usr/local/lib/python3.11/dist-packages/pm4py/visualization/heuristics_net/visualizer.py in apply(heu_net, parameters, variant)
#      59         Representation of the Heuristics Net
#      60     """
# ---> 61     return exec_utils.get_variant(variant).apply(heu_net, parameters=parameters)
#      62
#      63
#
# /usr/local/lib/python3.11/dist-packages/pm4py/visualization/heuristics_net/variants/pydotplus_vis.py in apply(heu_net, parameters)
#     331     file_name.close()
#     332
# --> 333     graph.write(file_name.name, format=image_format)
#     334     return file_name
#
# /usr/local/lib/python3.11/dist-packages/pydotplus/graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# /usr/local/lib/python3.11/dist-packages/pydotplus/graphviz.py in create(self, prog, format)
#    2002         stdout_output = list()
#    2003         while True:
# -> 2004             data = stdout.read()
#    2005             if not data:
#    2006                 break
#
# KeyboardInterrupt:
